# %% [markdown]
# # Prop 67 Analysis
#
# An analysis of Proposition 67, which is a California ballot proposition on the November 8, 2016 ballot. A "Yes" vote was to approve, and a "No" vote to reject, a statute that prohibits grocery and other stores from providing customers single–use plastic or paper carryout bags but permits sale of recycled paper bags and reusable bags.
#
# Proposition 67 passed with 53% of the vote. With its passage, Senate Bill 270, which bans plastic shopping bags, was upheld and went into effect. A related measure, Proposition 65, failed at the polls.

# %%
import pandas as pd

# %% [markdown]
# ### Read in the propositions and committees from CSV

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Read in the list of contributors to the ballot measure

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts
# Out:
# <bound method Series.value_counts of 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.committee_name.value_counts().reset_index()
# Out:
#                                                 index  committee_name
# 0   MILLION VOTER PROJECT ACTION FUND - YES ON 55,...               6
# 1        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))               4
# 2   PICO CALIFORNIA - YES ON 55, 56, AND 57 (NON P...               3
# 3   MILLION VOTER PROJECT ACTION FUND - YES ON 55 ...               3
# 4   PROTEUS ACTION LEAGUE NON-PROFIT 501 (C)(4) OR...               3
# 5   CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIA...               2
# 6   CALIFORNIA KIDS CAMPAIGN, YES ON PROPS 55 & 56...               2
# 7   COMMON SENSE KIDS ACTION, INC., YES ON PROPS. ...               2
# 8   AMERICAN PROGRESSIVE BAG ALLIANCE, A PROJECT O...               2
# 9   UNITED TEACHERS LOS ANGELES-POLITICAL ACTION C...               2
# 10  CALIFORNIA COMMON CAUSE -- YES ON 54 AND 59 (N...               2
# 11  SAN FRANCISCO POLICE OFFICERS ASSOCIATION ISSU...               2
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
prop = props[props.prop_name == "PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS."]

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 95  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 96  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 97  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 98  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 99  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#     ccdc_prop_id                                          prop_name  \
# 95            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 96            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 97            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 98            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 99            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 95                477                 1372900
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Merged proposition CSV and contributors CSV

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 1  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 2  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 3  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 4  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#    ccdc_prop_id                                          prop_name  \
# 0            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 1            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 2            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 3            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 4            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                477                 1372900
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6279 entries, 0 to 6278
# Data columns (total 20 columns):
# ocd_prop_id                     6279 non-null object
# calaccess_prop_id               6279 non-null int64
# ccdc_prop_id                    6279 non-null int64
# prop_name                       6279 non-null object
# ccdc_committee_id               6279 non-null int64
# calaccess_committee_id          6279 non-null int64
# committee_name_x                6279 non-null object
# committee_position              6279 non-null object
# committee_name_y                6279 non-null object
# calaccess_filing_id             6279 non-null int64
# date_received                   6279 non-null object
# contributor_lastname            6279 non-null object
# contributor_firstname           6211 non-null object
# contributor_city                6279 non-null object
# contributor_state               6278 non-null object
# contributor_zip                 6278 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 4470574.0

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6252 entries, 0 to 6278
# Data columns (total 20 columns):
# ocd_prop_id                     6252 non-null object
# calaccess_prop_id               6252 non-null int64
# ccdc_prop_id                    6252 non-null int64
# prop_name                       6252 non-null object
# ccdc_committee_id               6252 non-null int64
# calaccess_committee_id          6252 non-null int64
# committee_name_x                6252 non-null object
# committee_position              6252 non-null object
# committee_name_y                6252 non-null object
# calaccess_filing_id             6252 non-null int64
# date_received                   6252 non-null object
# contributor_lastname            6252 non-null object
# contributor_firstname           6211 non-null object
# contributor_city                6252 non-null object
# contributor_state               6251 non-null object
# contributor_zip                 6251 non-null object
# ...

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
support.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 1  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 2  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 3  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 4  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#    ccdc_prop_id                                          prop_name  \
# 0            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 1            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 2            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 3            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 4            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                477                 1372900
# ...

# %%
oppose.head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 128  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 129  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 130  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 131  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 132  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#      ccdc_prop_id                                          prop_name  \
# 128            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 129            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 130            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 131            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 132            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 128                478                 1372902
# ...

# %%
support.amount.sum()
# Out:
# 1789160.75

# %%
oppose.amount.sum()
# Out:
# 2681413.25

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.40020828421585236

# %%
oppose.amount.sum() / merged.amount.sum()
# Out:
# 0.59979171578414758

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 141   ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 132   ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 140   ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 142   ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 133   ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 5     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 134   ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 150   ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 6255  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 61    ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 59    ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 144   ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# ...

# %%
oppose.sort_values("amount", ascending=False).head(10)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 141  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 132  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 140  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 142  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 133  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 134  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 150  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 148  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 144  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 135  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#      ccdc_prop_id                                          prop_name  \
# 141            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# ...

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                     committee_name_x      amount
# 0  AMERICAN PROGRESSIVE BAG ALLIANCE, A PROJECT O...  2681413.25
# 5  YES ON 67 - PROTECT THE PLASTIC BAG BAN, SPONS...   861295.75
# 2  SAVE THE BAG BAN, YES ON 67, SPONSORED BY ENVI...   609365.00
# 1  CALIFORNIA GROCERS ASSOCIATION ISSUES COMMITTE...   200000.00
# 3  SAVE THE BAY ACTION FUND COMMITTEE TO SUPPORT ...    97050.00
# 4  YES ON 67 - CALIFORNIANS AGAINST WASTE - PROTE...    21450.00

# %%
merged.groupby(["contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                    contributor_lastname committee_position  \
# 713                                  HILEX POLY CO. LLC             OPPOSE
# 522                 FORMOSA PLASTICS CORPORATION U.S.A.             OPPOSE
# 1534                                     SUPERBAG CORP.             OPPOSE
# 12                                ADVANCE POLYBAG, INC.             OPPOSE
# 256                      CALIFORNIA GROCERS ASSOCIATION            SUPPORT
# 17    ALBERTSONS SAFEWAY (FORMERLY KNOWN AS SAFEWAY,...            SUPPORT
# 1184                                            PACKARD            SUPPORT
# 1217                                              PERRY            SUPPORT
# 257   CALIFORNIA GROCERS ASSOCIATION ISSUES COMMITTE...            SUPPORT
# 1261                                 RALPHS/FOOD 4 LESS            SUPPORT
# 1370                 SAVE THE BAY (NONPROFIT 501(C)(3))            SUPPORT
# ...

# %%
merged.head(2017)
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 0     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 1     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 2     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 3     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 4     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 5     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 6     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 7     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 8     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 9     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 10    ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 11    ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# ...

# %%
merged.groupby(["contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                    contributor_lastname committee_position  \
# 713                                  HILEX POLY CO. LLC             OPPOSE
# 522                 FORMOSA PLASTICS CORPORATION U.S.A.             OPPOSE
# 1534                                     SUPERBAG CORP.             OPPOSE
# 12                                ADVANCE POLYBAG, INC.             OPPOSE
# 256                      CALIFORNIA GROCERS ASSOCIATION            SUPPORT
# 17    ALBERTSONS SAFEWAY (FORMERLY KNOWN AS SAFEWAY,...            SUPPORT
# 1184                                            PACKARD            SUPPORT
# 1217                                              PERRY            SUPPORT
# 257   CALIFORNIA GROCERS ASSOCIATION ISSUES COMMITTE...            SUPPORT
# 1261                                 RALPHS/FOOD 4 LESS            SUPPORT
# 1370                 SAVE THE BAY (NONPROFIT 501(C)(3))            SUPPORT
# ...

# %%
merged[pd.isnull(merged.contributor_firstname)]
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 0     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 1     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 2     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 3     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 4     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 5     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 6     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 7     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 8     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 9     ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 10    ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 11    ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# ...

# %%
merged.drop('contributor_fullname', axis=1, inplace=True)

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 1  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 2  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 3  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 4  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#    ccdc_prop_id                                          prop_name  \
# 0            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 1            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 2            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 3            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 4            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                477                 1372900
# ...

# %% [markdown]
# ### Introduced a new column "contributor_fullname"

# %%
merged["contributor_fullname"] = merged["contributor_firstname"].map(str) + " " + merged["contributor_lastname"].map(str)

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 1  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 2  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 3  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 4  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#    ccdc_prop_id                                          prop_name  \
# 0            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 1            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 2            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 3            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 4            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                477                 1372900
# ...

# %%
merged["contributor_fullname"] = merged["contributor_fullname"].str.lstrip('nan')

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 1  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 2  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 3  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 4  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#    ccdc_prop_id                                          prop_name  \
# 0            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 1            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 2            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 3            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 4            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                477                 1372900
# ...

# %%
merged.groupby(["contributor_fullname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                    contributor_fullname committee_position  \
# 11                                   HILEX POLY CO. LLC             OPPOSE
# 10                  FORMOSA PLASTICS CORPORATION U.S.A.             OPPOSE
# 35                                       SUPERBAG CORP.             OPPOSE
# 0                                 ADVANCE POLYBAG, INC.             OPPOSE
# 4                        CALIFORNIA GROCERS ASSOCIATION            SUPPORT
# 1      ALBERTSONS SAFEWAY (FORMERLY KNOWN AS SAFEWAY...            SUPPORT
# 1058                                      JULIE PACKARD            SUPPORT
# 5      CALIFORNIA GROCERS ASSOCIATION ISSUES COMMITT...            SUPPORT
# 369                                        CLAIRE PERRY            SUPPORT
# 21                                   RALPHS/FOOD 4 LESS            SUPPORT
# 37                               THE NATURE CONSERVANCY            SUPPORT
# ...
